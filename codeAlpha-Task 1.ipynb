# %%
#TASK 1
class task:
  def __init__(self,len):
    self.len = len

  def fibo(self):
    cur = 1
    prev = 0
    for itr in range(self.len):
      next = cur + prev
      prev = cur
      cur = next
      print(next)
var_len = task(int(input("Enter the len of fibo : ")))
var_len.fibo()
# Out:
# Enter the lebn of fibo : 5
# 1
# 2
# 3
# 5
# 8
